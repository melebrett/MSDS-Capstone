# %%
import pandas as pd
import numpy as np

# %%
# read in scores.json
scores = pd.read_json('scores.json')

# %%
scores['scores'][1]
# Out:
# [{'dg_id': 14139,
#   'fin_text': '1',
#   'player_name': 'Thomas, Justin',
#   'round_1': {'course_name': 'Southern Hills Country Club',
#    'course_num': 611,
#    'course_par': 70,
#    'driving_acc': 0.5,
#    'driving_dist': 310.1,
#    'gir': 0.611,
#    'great_shots': 3,
#    'poor_shots': 0,
#    'prox_fw': 29.639,
#    'prox_rgh': 36.597,
#    'score': 67,
#    'scrambling': 0.714,
#    'sg_app': 1.838,
#    'sg_arg': 0.61,
#    'sg_ott': 0.203,
#    'sg_putt': 3.182,
#    'sg_t2g': 2.651,
#    'sg_total': 5.833,
#    'start_hole': 1,
#    'teetime': '1:14pm'},
#   'round_2': {'course_name': 'Southern Hills Country Club',
#    'course_num': 611,
#    'course_par': 70,
#    'driving_acc': 0.643,
#    'driving_dist': 312.1,
#    'gir': 0.889,
#    'great_shots': 3,
#    'poor_shots': 0,
#    'prox_fw': 26.996,
#    'prox_rgh': 38.423,
#    'score': 67,
#    'scrambling': 0.5,
#    'sg_app': 2.416,
#    'sg_arg': 0.295,
#    'sg_ott': 0.964,
#    'sg_putt': 1.927,
# ...

# %%
scores['scores'][5]
# Out:
# [{'dg_id': 16243,
#   'fin_text': '1',
#   'player_name': 'Koepka, Brooks',
#   'round_1': {'course_name': 'Bellerive CC',
#    'course_num': 534,
#    'course_par': 70,
#    'driving_acc': 0.786,
#    'driving_dist': 309,
#    'gir': 0.833,
#    'great_shots': 5,
#    'poor_shots': 2,
#    'prox_fw': 22.23,
#    'prox_rgh': 34.485,
#    'score': 69,
#    'scrambling': 0.667,
#    'sg_app': 0.45,
#    'sg_arg': -0.019,
#    'sg_ott': 2.273,
#    'sg_putt': -0.326,
#    'sg_t2g': 2.7039999999999997,
#    'sg_total': 2.378,
#    'start_hole': 1,
#    'teetime': '1:15pm'},
#   'round_2': {'course_name': 'Bellerive CC',
#    'course_num': 534,
#    'course_par': 70,
#    'driving_acc': 0.857,
#    'driving_dist': 312.3,
#    'gir': 0.778,
#    'great_shots': 5,
#    'poor_shots': 0,
#    'prox_fw': 15.982,
#    'prox_rgh': 72.748,
#    'score': 63,
#    'scrambling': 1,
#    'sg_app': 3.076,
#    'sg_arg': 0.017,
#    'sg_ott': 2.083,
#    'sg_putt': 1.416,
#    'sg_t2g': 5.178,
# ...

# %%
prs = pd.read_json('prs.json')

# %%
prs.head()
# Out:
#   Tour  Year  Season         EventName  EventID      PlayerName   DGID  \
# 0  pga  2023    2023  PGA Championship       33  Thomas, Justin  14139
# 1  pga  2023    2023  PGA Championship       33  Thomas, Justin  14139
# 2  pga  2023    2023  PGA Championship       33  Thomas, Justin  14139
# 3  pga  2023    2023  PGA Championship       33  Thomas, Justin  14139
# 4  pga  2022    2022  PGA Championship       33  Thomas, Justin  14139
#
#    FinText  RoundNum                     CourseName  ...  SGTtg  SGTotal  \
# 0        1         1  Quail Hollow-PGA Championship  ...  1.227    1.737
# 1        1         2  Quail Hollow-PGA Championship  ...  4.209    7.601
# 2        1         3  Quail Hollow-PGA Championship  ...  2.230    3.200
# 3        1         4  Quail Hollow-PGA Championship  ...  1.472    3.827
# 4        1         1  Quail Hollow-PGA Championship  ...  1.227    1.737
#
#    DrivingDist DrivingAcc    Gir  Scrambling  ProxRGH  ProxFW  GreatShots  \
# ...
